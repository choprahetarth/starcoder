# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('json', data_files='/u/choprahetarth/all_files/data/train_ftdata-new-small.json')
# Convert to pandas dataframe and print some rows
df = pd.DataFrame(dataset['train'])

# %%
df
# Out:
#                                                    input download_count  \
# 0                         name: Generate systemd service           1441
# 1                                     name: Test Changes           1928
# 2      name: Ensure Image Builder packages are instal...           2872
# 3               name: Create the nginxlog_exporter group          14120
# 4                     name: Enable apache2 proxy modules            613
# ...                                                  ...            ...
# 15241                           name: create vertica dir            621
# 15242  name: Assert that GPG verification was successful          19333
# 15243                    name: Install required packages           1212
# 15244       name: Include OS-specific variables (Debian)           1950
# 15245              name: Ensure user can deploy manpages           1212
#
#                                                     path  \
# 0              data/repos/jkrue/theia_ide/tasks/main.yml
# 1      data/repos/imcitius/ansible_transparent_huge_p...
# 2      data/repos/linux-system-roles/image_builder/ta...
# 3      data/repos/mbaran0v/ansible_role_prometheus_ng...
# 4      data/repos/hadrienpatte/subsonic/tasks/HTTP_se...
# ...                                                  ...
# 15241  data/repos/hpcloud-mon/monasca-persister/tasks...
# 15242         data/repos/ecgalaxy/aws_cli/tasks/main.yml
# 15243  data/repos/ccdc/cpp_required_tools/tasks/RedHa...
# 15244  data/repos/ecgalaxy/oracle_instantclient/tasks...
# 15245  data/repos/ccdc/cpp_required_tools/tasks/Darwi...
#
#                                        repo_name  \
# 0                                      theia_ide
# 1                 ansible_transparent_huge_pages
# 2                                  image_builder
# 3      ansible_role_prometheus_nginxlog_exporter
# 4                                       subsonic
# ...                                          ...
# 15241                          monasca-persister
# 15242                                    aws_cli
# 15243                         cpp_required_tools
# 15244                       oracle_instantclient
# 15245                         cpp_required_tools
#
#                                            download_link  \
# 0         https://old-galaxy.ansible.com/jkrue/theia_ide
# 1      https://old-galaxy.ansible.com/imcitius/ansibl...
# 2      https://old-galaxy.ansible.com/linux-system-ro...
# 3      https://old-galaxy.ansible.com/mbaran0v/ansibl...
# 4      https://old-galaxy.ansible.com/hadrienpatte/su...
# ...                                                  ...
# 15241  https://old-galaxy.ansible.com/hpcloud-mon/mon...
# 15242    https://old-galaxy.ansible.com/ecgalaxy/aws_cli
# 15243  https://old-galaxy.ansible.com/ccdc/cpp_requir...
# 15244  https://old-galaxy.ansible.com/ecgalaxy/oracle...
# 15245  https://old-galaxy.ansible.com/ccdc/cpp_requir...
#
#                                                   output            org_name  \
# 0      template:\n  src: theia-ide.service.j2\n  dest...               jkrue
# 1      command: cat /sys/kernel/mm/transparent_hugepa...            imcitius
# 2               package:\n  name: ''\n  state: present\n  linux-system-roles
# 3      group:\n  name: '{{ nginxlog_exporter_user }}'...            mbaran0v
# 4      apache2_module:\n  name: ''\n  state: present\...        hadrienpatte
# ...                                                  ...                 ...
# 15241  file: path=/opt/monasca/vertica state=director...         hpcloud-mon
# 15242  ansible.builtin.assert:\n  that:\n  - verifica...            ecgalaxy
# 15243  ansible.builtin.dnf:\n  name:\n  - zstd\n  - p...                ccdc
# 15244  ansible.builtin.include_vars: Debian.yml\nwhen...            ecgalaxy
# 15245  ansible.builtin.file:\n  path: /usr/local/shar...                ccdc
#
#                            license
# 0                     BSD-3-Clause
# 1      Apache-2.0-Short,Apache-2.0
# 2                     GPL-3.0-only
# 3
# 4                              MIT
# ...                            ...
# 15241
# 15242
# 15243                          MIT
# 15244
# 15245                          MIT
#
# [15246 rows x 8 columns]
